# %% [markdown]
# ## 创建模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

load_dotenv()

BASE_URL = os.getenv("SILICON_BASE_URL")
API_KEY = os.getenv("SILICON_API_KEY")

model = init_chat_model(
   model="Qwen/Qwen3-8B",
   model_provider="openai",
   base_url = BASE_URL,
   api_key = API_KEY
)  

print(type(model))
print(model.invoke("hi"))
print("=" * 50 + "\n")

stream = model.stream("简单介绍下你能做什么吧？")
for chunk in stream:
   print(chunk.content, end="", flush=True)
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>
# content='\n\nHello! How can I assist you today? 😊' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 129, 'prompt_tokens': 9, 'total_tokens': 138, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 117, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-8B', 'system_fingerprint': '', 'id': '019f047658e84c8dde92dc1af162fb20', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f0476-5858-7e83-8564-f385b40e148c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 129, 'total_tokens': 138, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 117}}
# ==================================================
#
#
#
# 你好！我是通義千問，一個由通義實驗室開發的超大規模語言模型。我的主要能力包括：
#
# 1. **廣泛知識覆蓋**
#    我擁有語言、科學、文化、技術等多領域的知識，能回答各種問題。但請注意，我的知識截止於2024年10月，無法獲取最新數據。
#
# 2. **語言理解與生成**
#    我支持中英文互動，能理解和生成多種語言的文本。例如：
#    - 翻譯文章、對話
#    - 撰寫小說、詩歌、文案
#    - 整理會議紀要、書面報告
#    - 過濾敏感詞語，提供適當的語言風格建議
#
# 3. **多任務處理**
#    可同時處理多個任務，例如：
#    - 分析數據並生成視覺化圖表
#    - 制定計劃或提供建議
#    - 編寫程式碼（支持多種語言）
#    - 解析複雜的邏輯問題
#
# 4. **邏輯推理與問題解決**
#    我能進行邏輯推理、數學計算，並解釋推理過程。例如：
#    - 解答數學題、物理題
#    - 分析因果關係，推導結論
#    - 解決需要步驟分解的問題
#
# 5. **創意與思維激發**
#    可幫助產生創意，例如：
#    - 編寫故事、角色設定
#    - 提出新點子或解決方案
#    - 設計遊戲、活動方案
#    - 教授語言學習技巧
#
# 6. **互動方式靈活**
#    我能根據需要調整語言風格，例如：
#    - 輕鬆幽默的對話
#    - 專業嚴謹的分析
#    - 建議和指導
#    - 遊戲或測試互動
#
# 如果你有具體的問題或需求，歡迎隨時告訴我，我會盡力提供幫助！ 😊
